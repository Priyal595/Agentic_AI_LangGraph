# %%
# Prompt Chaining
from langgraph.graph import StateGraph, START, END
from langchain_community.chat_models import ChatOllama
from typing import TypedDict

# %%
model = ChatOllama(model="llama3")
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_1549332\1578714631.py:1: LangChainDeprecationWarning: The class `ChatOllama` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the `langchain-ollama package and should be used instead. To use it run `pip install -U `langchain-ollama` and import as `from `langchain_ollama import ChatOllama``.
#   model = ChatOllama(model="llama3")

# %%
class BlogState(TypedDict):
    title : str
    outline: str
    content: str

# %%
def create_outline(state: BlogState) -> BlogState:
    title = state['title']
    prompt = f" Generate a detailed outlined for a blog on the topic {title}"
    outline = model.invoke(prompt).content
    state['outline'] = outline
    return state

# %%
def create_blog(state: BlogState) -> BlogState:
    title, outline = state['title'], state['outline']
    prompt = f"Write a detailed blog on the title {title} using the following outline\n {outline}"
    content = model.invoke(prompt).content
    state['content'] = content
    return state

# %%
graph = StateGraph(BlogState)
graph.add_node('create_outline', create_outline)
graph.add_node('create_blog', create_blog)

graph.add_edge(START, 'create_outline')
graph.add_edge('create_outline', 'create_blog')
graph.add_edge('create_blog', END)

wf= graph.compile()

# %%
initial_state = {'title' : 'Rise of AI in India'}
final = wf.invoke(initial_state)
print(final)
# Out:
# {'title': 'Rise of AI in India', 'outline': 'Here is a detailed outline for a blog on the topic "Rise of AI in India":\n\n**I. Introduction**\n\n* Brief overview of Artificial Intelligence (AI) and its significance\n* Explanation of why India is an attractive market for AI adoption\n* Thesis statement: The rise of AI in India is transforming industries, creating new job opportunities, and driving economic growth.\n\n**II. Current State of AI in India**\n\n* Overview of the current AI landscape in India\n* Discussion of the government\'s initiatives to promote AI adoption (e.g., AI for All program)\n* Statistics on the number of AI startups in India, funding received, and notable AI-related acquisitions\n\n**III. Industries Impacted by AI in India**\n\n* Healthcare: Examples of AI-powered healthcare solutions, such as disease diagnosis, medical imaging analysis, and patient monitoring\n* Finance: Discussion of AI-powered banking and financial services, including chatbots, fraud detection, and personalized investment advice\n* Retail: Overview of AI-powered retail solutions, including customer service chatbots, product recommendations, and supply chain optimization\n* Education: Examples of AI-powered education solutions, such as adaptive learning systems, natural language processing-based tutoring, and virtual assistants\n\n**IV. Job Market Impact**\n\n* Discussion of the potential job displacement caused by AI adoption in India\n* Examples of new job opportunities created by AI (e.g., AI engineers, data scientists)\n* Statistics on the growing demand for AI-related skills in India\n\n**V. Challenges and Limitations**\n\n* Discussion of the challenges faced by Indian organizations in adopting AI, including data quality issues, lack of domain expertise, and regulatory hurdles\n* Overview of the limitations of current AI technology in India, including biases in training datasets and limitations of rule-based systems\n\n**VI. Future Outlook**\n\n* Predictions on the future growth of AI adoption in India\n* Discussion of emerging trends and technologies in Indian AI, such as explainable AI, human-AI collaboration, and edge AI\n* Conclusion: The rise of AI in India is poised to drive economic growth, create new job opportunities, and transform industries.\n\n**VII. Call to Action**\n\n* Encouragement for readers to explore AI-related training and upskilling opportunities\n* Discussion of the importance of developing a strong AI ecosystem in India\n\nThis outline should provide a comprehensive structure for your blog on the rise of AI in India. Good luck with your writing!', 'content': '**The Rise of AI in India: Transforming Industries, Creating Jobs, and Driving Growth**\n\nArtificial Intelligence (AI) has become a game-changer globally, and India is no exception. As one of the fastest-growing economies, India presents an attractive market for AI adoption, with its vast population, growing middle class, and increasing digitization. In this blog, we\'ll explore the current state of AI in India, industries impacted by AI, job market implications, challenges, and limitations, as well as the future outlook.\n\n**I. Introduction**\n\nArtificial Intelligence has revolutionized various sectors, from healthcare to finance, retail, and education. Its significance lies in its ability to automate repetitive tasks, analyze complex data, and make informed decisions. India\'s unique blend of demographic dividend, entrepreneurial spirit, and government initiatives makes it an attractive market for AI adoption.\n\nThe rise of AI in India is transforming industries, creating new job opportunities, and driving economic growth. As the government focuses on promoting AI adoption through initiatives like "AI for All," the potential for growth is immense.\n\n**II. Current State of AI in India**\n\nIndia\'s AI landscape is rapidly evolving, with a growing number of startups, research institutions, and corporations investing in AI technology. The governme ...

# %%
print(final['outline'])
# Out:
# Here is a detailed outline for a blog on the topic "Rise of AI in India":
#
# **I. Introduction**
#
# * Brief overview of Artificial Intelligence (AI) and its significance
# * Explanation of why India is an attractive market for AI adoption
# * Thesis statement: The rise of AI in India is transforming industries, creating new job opportunities, and driving economic growth.
#
# **II. Current State of AI in India**
#
# * Overview of the current AI landscape in India
# * Discussion of the government's initiatives to promote AI adoption (e.g., AI for All program)
# * Statistics on the number of AI startups in India, funding received, and notable AI-related acquisitions
#
# **III. Industries Impacted by AI in India**
#
# * Healthcare: Examples of AI-powered healthcare solutions, such as disease diagnosis, medical imaging analysis, and patient monitoring
# * Finance: Discussion of AI-powered banking and financial services, including chatbots, fraud detection, and personalized investment advice
# * Retail: Overview of AI-powered retail solutions, including customer service chatbots, product recommendations, and supply chain optimization
# * Education: Examples of AI-powered education solutions, such as adaptive learning systems, natural language processing-based tutoring, and virtual assistants
#
# **IV. Job Market Impact**
#
# * Discussion of the potential job displacement caused by AI adoption in India
# * Examples of new job opportunities created by AI (e.g., AI engineers, data scientists)
# * Statistics on the growing demand for AI-related skills in India
#
# **V. Challenges and Limitations**
#
# * Discussion of the challenges faced by Indian organizations in adopting AI, including data quality issues, lack of domain expertise, and regulatory hurdles
# * Overview of the limitations of current AI technology in India, including biases in training datasets and limitations of rule-based systems
#
# **VI. Future Outlook**
#
# * Predictions on the future growth of AI adoption in India
# * Discussion of emerging trends and technologies in Indian AI, such as explainable AI, human-AI collaboration, and edge AI
# * Conclusion: The rise of AI in India is poised to drive economic growth, create new job opportunities, and transform industries.
#
# **VII. Call to Action**
#
# * Encouragement for readers to explore AI-related training and upskilling opportunities
# * Discussion of the importance of developing a strong AI ecosystem in India
#
# This outline should provide a comprehensive structure for your blog on the rise of AI in India. Good luck with your writing!

# %%
print(final['content'])
# Out:
# **The Rise of AI in India: Transforming Industries, Creating Jobs, and Driving Growth**
#
# Artificial Intelligence (AI) has become a game-changer globally, and India is no exception. As one of the fastest-growing economies, India presents an attractive market for AI adoption, with its vast population, growing middle class, and increasing digitization. In this blog, we'll explore the current state of AI in India, industries impacted by AI, job market implications, challenges, and limitations, as well as the future outlook.
#
# **I. Introduction**
#
# Artificial Intelligence has revolutionized various sectors, from healthcare to finance, retail, and education. Its significance lies in its ability to automate repetitive tasks, analyze complex data, and make informed decisions. India's unique blend of demographic dividend, entrepreneurial spirit, and government initiatives makes it an attractive market for AI adoption.
#
# The rise of AI in India is transforming industries, creating new job opportunities, and driving economic growth. As the government focuses on promoting AI adoption through initiatives like "AI for All," the potential for growth is immense.
#
# **II. Current State of AI in India**
#
# India's AI landscape is rapidly evolving, with a growing number of startups, research institutions, and corporations investing in AI technology. The government has launched various programs to promote AI adoption, such as the "AI for All" program, which aims to make AI accessible to all.
#
# According to recent statistics:
#
# * Over 1,000 AI startups have emerged in India since 2015.
# * These startups have received significant funding, with some notable deals exceeding $100 million.
# * Indian companies have made several AI-related acquisitions, demonstrating the growing interest in AI technology.
#
# **III. Industries Impacted by AI in India**
#
# AI is transforming various industries in India, creating new opportunities and challenges.
#
# 1. **Healthcare:** AI-powered healthcare solutions are improving disease diagnosis, medical imaging analysis, patient monitoring, and predictive analytics.
# 2. **Finance:** AI-powered banking and financial services include chatbots for customer service, fraud detection, personalized investment advice, and risk assessment.
# 3. **Retail:** AI-powered retail solutions offer customer service chatbots, product recommendations, supply chain optimization, and inventory management.
# 4. **Education:** AI-powered education solutions include adaptive learning systems, natural language processing-based tutoring, virtual assistants, and personalized learning pathways.
#
# **IV. Job Market Impact**
#
# The rise of AI in India is creating both job displacement and new job opportunities. While some jobs may be automated, others will require human skills like creativity, empathy, and problem-solving.
#
# 1. **Job Displacement:** AI may displace jobs that involve repetitive tasks, data entry, or simple decision-making.
# 2. **New Job Opportunities:** AI is creating demand for skilled professionals like:
# 	* AI engineers and data scientists
# 	* Machine learning specialists and natural language processing experts
# 	* Data analysts and business intelligence professionals
#
# **V. Challenges and Limitations**
#
# Despite the growth potential of AI in India, several challenges and limitations need to be addressed:
#
# 1. **Data Quality Issues:** Poor-quality data can lead to biased or inaccurate AI models.
# 2. **Lack of Domain Expertise:** Indian organizations may struggle to find domain experts who understand AI technology.
# 3. **Regulatory Hurdles:** AI applications may require regulatory approvals, which can be time-consuming and complex.
# 4. **Biases in Training Datasets:** AI systems trained on biased data sets can perpetuate existing biases.
#
# **VI. Future Outlook**
#
# The future of AI in India looks promising:
#
# 1. **Explainable AI:** There is a growing need for explainable AI that provides transparency into decision-making processes.
# 2. **Human-AI Collaboration:** As AI becomes more pervasive, there will be a greater emphasis on human-AI collaboration and teamwork.
# 3. **Edge AI:** Edge AI will play a crucial role in processing data closer to the source, reducing latency, and improving real-time decision-making.
#
# **VII. Call to Action**
#
# As AI continues to transform industries in India, it is essential for individuals to upskill and reskill:
#
# 1. **Explore AI-related Training and Up-skilling Opportunities:** Invest in yourself by learning AI skills like machine learning, data science, or natural language processing.
# 2. **Develop a Strong AI Ecosystem:** Encourage innovation, entrepreneurship, and collaboration to build a robust AI ecosystem in India.
#
# In conclusion, the rise of AI in India is poised to drive economic growth, create new job opportunities, and transform industries. As we navigate this exciting landscape, it's crucial to address challenges and limitations, while embracing the benefits that AI has to offer.
